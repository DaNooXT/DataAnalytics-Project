# %%
import pandas as pd

df_clients = pd.read_csv("../data/raw/clients.csv")
df_orders = pd.read_csv("../data/raw/orders.csv")
df_peyments = pd.read_csv("../data/raw/payments.csv")
df_products = pd.read_csv("../data/raw/products.csv")

display(df_clients.head())
display(df_clients.info())
display(df_clients.describe())
display(df_clients.isnull().sum())
display(df_clients.duplicated().sum())
# Out:
#    cliente_id    nome sobrenome sexo idade                         email  \
# 0           1  Arthur    Santos    M    19    arthur.santos755@gmail.com
# 1           2    Theo  Teixeira    F    52    theo.teixeira829@gmail.com
# 2           3    João   Freitas    F    47   joão.freitas301@outlook.com
# 3           4  Arthur  Carvalho    M    28  arthur.carvalho719@gmail.com
# 4           5    Caio   Moreira    M    21                           NaN
#
#          telefone          cidade estado data_cadastro
# 0  (65)91520-1488  Rio de Janeiro     SP    2025-02-23
# 1  (46)93547-4527   Florianópolis     PR    2023-12-06
# 2          abc123        Londrina     RJ    2024-02-18
# 3  (31)98573-7216        Curitiba     MT    2023-03-26
# 4  (94)99179-7482         Goiânia     CE    2025-02-23
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
# ...

# %%
display(df_orders.head())
display(df_orders.info())
display(df_orders.describe())
display(df_orders.isnull().sum())
display(df_orders.duplicated().sum())
# Out:
#    pedido_id  cliente_id  produto_id quantidade  preco_unitario  desconto  \
# 0          1         655         115          1        11128.43       NaN
# 1          2         666         719          9         6304.41      0.13
# 2          3         368         868          6         9063.82      0.24
# 3          4         792         297          2        12832.66      0.26
# 4          5         251         168          8         5704.24      0.30
#
#     frete valor_total     status data_pedido
# 0   29.54    10378.98       PAGO  2025-02-23
# 1   48.95    49412.48       PAGO  2022-07-09
# 2  112.16    41443.18   PENDENTE  05-23-2022
# 3   63.22    19055.56       PAGO  2022-12-17
# 4     NaN    32043.34  CANCELADO  2022-05-16
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   pedido_id       10000 non-null  int64
# ...

# %%
display(df_peyments.head())
display(df_peyments.info())
display(df_peyments.describe())
display(df_peyments.isnull().sum())
display(df_peyments.duplicated().sum())
# Out:
#    pagamento_id  pedido_id forma_pagamento parcelas bandeira_cartao  \
# 0             1       1825             PIX       12             NaN
# 1             2       8929        Dinheiro        4             NaN
# 2             3       9892          Boleto        1             NaN
# 3             4       4742             PIX        4             NaN
# 4             5       4011          Cartão        8             NaN
#
#   valor_pago     status data_pagamento
# 0    4139.94       PAGO     2022-02-24
# 1    6749.15   PENDENTE     2024-01-06
# 2   10951.38  ESTORNADO     2022-04-04
# 3   12999.93   PENDENTE     2022-12-17
# 4    5704.24  ESTORNADO     2023-03-09
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pagamento_id     10000 non-null  int64
#  1   pedido_id        10000 non-null  int64
# ...

# %%
display(df_products.head())
display(df_products.info())
display(df_products.isnull().sum())
display(df_products.duplicated().sum())
display(df_products['nome'].unique())
# Out:
#    produto_id           nome categoria     marca    preco estoque  \
# 0           1    Mouse Gamer     Fonte  Logitech  9598.61      12
# 1           2     Fonte 650W       NaN  Logitech  6340.39      15
# 2           3  Headset Gamer       SSD        LG  6749.15     -10
# 3           4   Memória 16GB   Headset      Dell  5062.19      47
# 4           5     Fonte 650W        HD  Kingston      mil     193
#
#   data_cadastro
# 0    2025-01-21
# 1    2025-01-21
# 2    2023-03-17
# 3    2024-07-29
# 4    2023-01-29
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   produto_id     1000 non-null   int64
#  1   nome           1000 non-null   str
#  2   categoria      985 non-null    str
#  3   marca          1000 non-null   str
#  4   preco          981 non-null    str
#  5   estoque        980 non-null    str
# ...
