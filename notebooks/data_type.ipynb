# %%
import pandas as pd
import numpy as np

df_products = pd.read_csv("../data/raw/products.csv")



display(df_products)
# Out:
# <StringArray>
# [         'Fonte',              nan,            'SSD',        'Headset',
#              'HD',        'Memória',        'Teclado',       'Gabinete',
#         'Monitor',      'Placa Mãe',     'Impressora', 'Placa de Vídeo',
#           'Mouse',       'notebook',         'Webcam',       'Notebook',
#     'Processador',             'hd',      'Notebooks',          'mouse',
#     'Placa video',       'NOTEBOOK',       'Monitor ']
# Length: 23, dtype: str
# <StringArray>
# [ '12',  '15', '-10',  '47', '193', '116', '189', '236', '117', '452',
#  ...
#  '336',  '34', '375',   '2', '474', '408', '150',   '1', '160', '180']
# Length: 426, dtype: str
#      produto_id           nome categoria     marca     preco estoque  \
# 0             1    Mouse Gamer     Fonte  Logitech   9598.61      12
# 1             2     Fonte 650W       NaN  Logitech   6340.39      15
# 2             3  Headset Gamer       SSD        LG   6749.15     -10
# ...
