# %%
import pandas as pd
import numpy as np
# Out:
#     pagamento_id  pedido_id forma_pagamento  parcelas   bandeira_cartao  \
# 0              1       1825             PIX        12      SEM BANDEIRA
# 1              2       8929        DINHEIRO         4      SEM BANDEIRA
# 2              3       9892          BOLETO         1      SEM BANDEIRA
# 3              4       4742             PIX         4      SEM BANDEIRA
# 4              5       4011          CARTÃO         8      SEM BANDEIRA
# 5              6       9293          BOLETO         4      SEM BANDEIRA
# 6              7       1490             PIX         2      SEM BANDEIRA
# 7              8       8798          CARTAO        11      SEM BANDEIRA
# 8              9       8318          CARTÃO         3  AMERICAN EXPRESS
# 9             10       3947             PIX         2      SEM BANDEIRA
# 10            11       6538             PIX         8      SEM BANDEIRA
# 11            12       1161          CARTÃO         5  AMERICAN EXPRESS
# ...
