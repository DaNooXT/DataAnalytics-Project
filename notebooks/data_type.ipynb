# %%
import pandas as pd
import numpy as np

df_clients = pd.read_csv("../data/raw/clients.csv")
df_orders = pd.read_csv("../data/raw/orders.csv")
df_peyments = pd.read_csv("../data/raw/payments.csv")
df_products = pd.read_csv("../data/raw/products.csv")

df_clients["idade"] = pd.to_numeric(
    df_clients["idade"],
    errors="coerce"
)

df_clients.loc[
    df_clients["idade"] <= 0,
    "idade"
] = np.nan


df_clients["idade"] = df_clients["idade"].fillna(
    df_clients["idade"].median()
    )
today = pd.Timestamp.today()

df_clients["data_cadastro"] = (
    pd.to_datetime(
        df_clients["data_cadastro"], 
        errors="coerce", 
        dayfirst=False
        )
    )

df_clients = df_clients[
    df_clients["data_cadastro"] <= today
    ]

df_clients["data_cadastro"] = df_clients["data_cadastro"].dt.strftime("%y-%m-%d")

display(df_clients.info())
display(df_clients.isnull().sum())
# Out:
# <class 'pandas.DataFrame'>
# Index: 916 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cliente_id     916 non-null    int64
#  1   nome           916 non-null    str
#  2   sobrenome      916 non-null    str
#  3   sexo           916 non-null    str
#  4   idade          916 non-null    float64
#  5   email          901 non-null    str
#  6   telefone       847 non-null    str
#  7   cidade         860 non-null    str
#  8   estado         916 non-null    str
#  9   data_cadastro  916 non-null    str
# dtypes: float64(1), int64(1), str(8)
# memory usage: 78.7 KB
# None
# cliente_id        0
# nome              0
# sobrenome         0
# sexo              0
# idade             0
# email            15
# telefone         69
# cidade           56
# estado            0
# data_cadastro     0
# dtype: int64
